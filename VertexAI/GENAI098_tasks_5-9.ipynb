# %% [markdown]
# ## Task 5. Create and initialize a new Colab Enterprise notebook

# %%
# %pip --version
# Out:
# pip 25.1.1 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)

# %%
# %pip install pip==24.0
# Out:
# Collecting pip==24.0
#   Downloading pip-24.0-py3-none-any.whl.metadata (3.6 kB)
# Downloading pip-24.0-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.5 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# Successfully installed pip-24.0

# %%
# %pip --version
# Out:
# pip 24.0 from /usr/local/lib/python3.11/dist-packages/pip (python 3.11)

# %%
# %pip install --upgrade --user --quiet "google-cloud-aiplatform[agent_engines,evaluation,langchain]" \
    "langchain_google_vertexai" \
    "google-cloud-aiplatform" \
    "google-cloud-logging" \
    "google-cloud-aiplatform[autologging]" \
    "cloudpickle==3.0.0" \
    "pydantic>=2.10" \
    "requests"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.9/17.9 MB 76.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 13.6 MB/s eta 0:00:00
#   WARNING: The scripts databricks and dbfs are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts mlflow and mlp are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# ==> Restart the session now.

# %%
# General
import random
import string
import google.cloud.logging
import logging

from IPython.display import HTML, Markdown, display
import pandas as pd

# Build agent
import vertexai
from google.cloud import aiplatform
from vertexai import agent_engines

# Evaluate agent
from vertexai.preview.evaluation import EvalTask
from vertexai.preview.evaluation.metrics import (
    PointwiseMetric,
    PointwiseMetricPromptTemplate,
    TrajectorySingleToolUse,
)
from vertexai.preview.reasoning_engines import LangchainAgent

# Do not remove logging section
client = google.cloud.logging.Client()
client.setup_logging()

# %%
# Variable initialization
PROJECT_ID ="qwiklabs-gcp-03-d419223c1a66"
LOCATION ="us-central1"
BUCKET_URI ="gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket"
EXPERIMENT_NAME ="evaluate-agent"

import vertexai

# Initialize vertexai
vertexai.init(
    # Fill in the appropriate configuration
    project=PROJECT_ID,
    location=LOCATION,
    staging_bucket=BUCKET_URI,
    experiment=EXPERIMENT_NAME
)
# Out:
# INFO:root:MetadataStore default not found.
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-c191706a-aeeb-4b90-8799-13a60b194e79" href="#view-view-vertex-resource-c191706a-aeeb-4b90-8799-13a60b194e79">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-c191706a-aeeb-4b90-8799-13a60b194e79');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %% [markdown]
# ## Task 6. Build agent and execute a query

# %%
# General
import random
import string

from IPython.display import HTML, Markdown, display

# Build agent
import vertexai
from google.cloud import aiplatform
from vertexai import agent_engines

from vertexai.preview.reasoning_engines import LangchainAgent

# %%
def get_product_details(product_name: str):
    """Gathers basic details about a product."""
    details = {
        "mens blue shorts": "Elevate your summer style with these tailored blue dress shorts. Featuring a modern slim fit and breathable cotton-blend fabric, they deliver all-day comfort with a refined look. Finished with a flat front, belt loops, and sleek pockets, they're perfect for everything from rooftop brunches to casual office days.",
        "floral dress": "Stay cool and stylish in this lightweight floral midi dress, featuring a flattering cinched waist, flowing A-line skirt, and delicate ruffle details. Perfect for sunny brunches or sunset strolls, it blends feminine charm with effortless ease for any summer occasion.",
        "garden furniture": "Create your perfect outdoor retreat with this stylish, weather-resistant garden furniture set featuring plush cushions, timeless design, and all-day comfort — ideal for relaxing, entertaining, or enjoying the outdoors in style.",
        "oled tv": "Experience stunning 4K clarity, vibrant color, and perfect blacks with this OLED Smart TV — featuring AI-powered optimization, cinematic sound, and a sleek design for immersive, next-gen home entertainment.",
        "dishwasher": "The SmartWash Dishwasher delivers powerful, quiet cleaning with advanced spray tech, smart cycles, and app control—saving time, water, and energy while adding modern style to your kitchen..",
    }
    return details.get(product_name, "Product details not found.")


def get_product_price(product_name: str):
    """Gathers price about a product."""
    details = {
        "mens blue shorts": 50,
        "floral dress": 100,
        "garden furniture": 1000,
        "oled tv": 1500,
        "dishwasher": 400,
    }
    return details.get(product_name, "Product price not found.")

# %%
model_name="gemini-2.0-flash"

# %%
local_1p_agent = LangchainAgent(
    model=model_name,
    tools=[get_product_details, get_product_price],
    agent_executor_kwargs={"return_intermediate_steps": True},
)

# %%
response = local_1p_agent.query(input="Get product details for garden furniture")
display(Markdown(response["output"]))
# Out:
# Ok. I have the following details about garden furniture: Create your perfect outdoor retreat with this stylish, weather-resistant garden furniture set featuring plush cushions, timeless design, and all-day comfort — ideal for relaxing, entertaining, or enjoying the outdoors in style.

# %%
response = local_1p_agent.query(input="Get product price for garden furniture")
display(Markdown(response["output"]))
# Out:
# The price of the garden furniture is 1000.

# %%
remote_1p_agent = agent_engines.create(
    local_1p_agent,
    requirements=[
        "google-cloud-aiplatform[agent_engines,langchain]",
        "langchain_google_vertexai",
        "cloudpickle==3.0.0",
        "pydantic>=2.10",
        "requests",
    ],
)
# Out:
# INFO:vertexai.agent_engines:Identified the following requirements: {'pydantic': '2.11.7', 'google-cloud-aiplatform': '1.100.0', 'cloudpickle': '3.0.0'}
# INFO:vertexai.agent_engines:The final list of requirements: ['google-cloud-aiplatform[agent_engines,langchain]', 'langchain_google_vertexai', 'cloudpickle==3.0.0', 'pydantic>=2.10', 'requests']
# INFO:vertexai.agent_engines:Using bucket qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket
# INFO:vertexai.agent_engines:Wrote to gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/agent_engine/agent_engine.pkl
# INFO:vertexai.agent_engines:Writing to gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/agent_engine/requirements.txt
# INFO:vertexai.agent_engines:Creating in-memory tarfile of extra_packages
# INFO:vertexai.agent_engines:Writing to gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/agent_engine/dependencies.tar.gz
# INFO:vertexai.agent_engines:Creating AgentEngine
# INFO:vertexai.agent_engines:Create AgentEngine backing LRO: projects/71777722578/locations/us-central1/reasoningEngines/7535340213241905152/operations/6041099341249118208
# INFO:vertexai.agent_engines:View progress and logs at https://console.cloud.google.com/logs/query?project=qwiklabs-gcp-03-d419223c1a66
# INFO:vertexai.agent_engines:AgentEngine created. Resource name: projects/71777722578/locations/us-central1/reasoningEngines/7535340213241905152
# INFO:vertexai.agent_engines:To use this AgentEngine in another session:
# INFO:vertexai.agent_engines:agent_engine = vertexai.agent_engines.get('projects/71777722578/locations/us-central1/reasoningEngines/7535340213241905152')

# %%
response = remote_1p_agent.query(input="Get product details for garden furniture")
display(Markdown(response["output"]))
# Out:
# The garden furniture set is stylish and weather-resistant, featuring plush cushions and a timeless design. It's designed for relaxation, entertaining, and enjoying the outdoors in style.

# %%
response = remote_1p_agent.query(input="Get product price for garden furniture")
display(Markdown(response["output"]))
# Out:
# The price of the garden furniture is 1000.

# %% [markdown]
# ## Task 7. Evaluate the agent using Single Tool Selection

# %%
eval_data = {
    "prompt": [
        "Get price for mens blue shorts",
        "Get product details and price for floral dress",
    ],
    "reference_trajectory": [
        [
            {
                "tool_name": "get_product_price",
                "tool_input": {"product_name": "mens blue shorts"},
            }
        ],
        [
            {
                "tool_name": "get_product_details",
                "tool_input": {"product_name": "floral dress"},
            },
            {
                "tool_name": "get_product_price",
                "tool_input": {"product_name": "floral dress"},
            },
        ],
    ],
}

eval_sample_dataset = pd.DataFrame(eval_data)

# %%
EXPERIMENT_RUN = "qwiklabs-gcp-03-d419223c1a66-single-tool-use"

single_tool_usage_metrics = [TrajectorySingleToolUse(tool_name="get_product_price")]

single_tool_call_eval_task = EvalTask(
    # Fill in the appropriate configuration
    dataset=eval_sample_dataset,
    metrics=single_tool_usage_metrics,
    experiment=EXPERIMENT_NAME,
    output_uri_prefix=BUCKET_URI + "/single-metric-eval",
)


single_tool_call_eval_result = single_tool_call_eval_task.evaluate(
    runnable=remote_1p_agent, experiment_run_name=EXPERIMENT_RUN
)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-7cb7e89d-8847-486c-ad6e-0e051ef9a6b1" href="#view-view-vertex-resource-7cb7e89d-8847-486c-ad6e-0e051ef9a6b1">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-7cb7e89d-8847-486c-ad6e-0e051ef9a6b1');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-739c4c3c-361c-483c-b862-c4946e651bf1" href="#view-view-vertex-resource-739c4c3c-361c-483c-b862-c4946e651bf1">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-739c4c3c-361c-483c-b862-c4946e651bf1');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs/evaluate-agent-qwiklabs-gcp-03-d419223c1a66-single-tool-use?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs/evaluate-agent-qwiklabs-gcp-03-d419223c1a66-single-tool-use?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# INFO:vertexai.preview.evaluation.eval_task:Logging Eval experiment evaluation metadata: {'output_file': 'gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/single-metric-eval/eval_results_2025-06-28-21-36-14-9cb3c.csv'}
# 100%|██████████| 2/2 [00:01<00:00,  1.45it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 2 responses are successfully generated from the runnable.
# INFO:vertexai.preview.evaluation._evaluation:Computing metrics with a total of 2 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 2/2 [00:00<00:00, 12.19it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 2 metric requests are successfully computed.
# INFO:vertexai.preview.evaluation._evaluation:Evaluation Took:0.17666605799968238 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-9e0d0070-0867-46de-a3eb-9a93afa347d6" href="#view-view-vertex-resource-9e0d0070-0867-46de-a3eb-9a93afa347d6">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-9e0d0070-0867-46de-a3eb-9a93afa347d6');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-c05d5941-317a-4183-aa73-90c932b90fd2" href="#view-view-vertex-resource-c05d5941-317a-4183-aa73-90c932b90fd2">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-c05d5941-317a-4183-aa73-90c932b90fd2');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/storage/browser/_details/qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/single-metric-eval/eval_results_2025-06-28-21-36-14-9cb3c/eval_results_2025-06-28-21-36-14-9cb3c.csv;colab_enterprise=gen_ai_evaluation');
#               } else {
#                 window.open('https://console.cloud.google.com/storage/browser/_details/qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/single-metric-eval/eval_results_2025-06-28-21-36-14-9cb3c/eval_results_2025-06-28-21-36-14-9cb3c.csv;colab_enterprise=gen_ai_evaluation', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %%
display_eval_report(single_tool_call_eval_result)
# Out:
# ### Summary Metrics
#    row_count  trajectory_single_tool_use/mean  trajectory_single_tool_use/std  \
# 0        2.0                              1.0                             0.0
#
#    latency_in_seconds/mean  latency_in_seconds/std  failure/mean  failure/std
# 0                 1.174266                0.236169           0.0          0.0
# ### Row-wise Metrics
#                                            prompt  \
# 0                  Get price for mens blue shorts
# 1  Get product details and price for floral dress
#
#                                 reference_trajectory  \
# 0  [{'tool_name': 'get_product_price', 'tool_inpu...
# 1  [{'tool_name': 'get_product_details', 'tool_in...
#
#                                             response latency_in_seconds  \
# 0           The price for mens blue shorts is $50.\n           1.007269
# 1  OK. I have the following information about the...           1.341263
#
#   failure                               predicted_trajectory  \
# 0       0  [{'tool_name': 'get_product_price', 'tool_inpu...
# 1       0  [{'tool_name': 'get_product_details', 'tool_in...
#
#    trajectory_single_tool_use/score
# 0                               1.0
# 1                               1.0

# %% [markdown]
# ## Task 8. Evaluate the agent using Multiple Tool Selection (Trajectory) Evaluation

# %%
EXPERIMENT_RUN = "qwiklabs-gcp-03-d419223c1a66-agent-trajectory-evaluation"

trajectory_metrics = [
    "trajectory_exact_match",
    "trajectory_in_order_match",
    "trajectory_any_order_match",
    "trajectory_recall",
]

trajectory_eval_task = EvalTask(
    # Fill in the appropriate configuration
    dataset=eval_sample_dataset,
    metrics=trajectory_metrics,
    experiment=EXPERIMENT_NAME,
    output_uri_prefix=BUCKET_URI + "/single-metric-eval",
)

trajectory_eval_result = trajectory_eval_task.evaluate(runnable=remote_1p_agent,experiment_run_name=EXPERIMENT_RUN)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-32f92aba-81bc-47ae-ba47-6a67e21703c1" href="#view-view-vertex-resource-32f92aba-81bc-47ae-ba47-6a67e21703c1">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-32f92aba-81bc-47ae-ba47-6a67e21703c1');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-58888a68-c32e-43ec-978c-acf6a0ff9c41" href="#view-view-vertex-resource-58888a68-c32e-43ec-978c-acf6a0ff9c41">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-58888a68-c32e-43ec-978c-acf6a0ff9c41');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs/evaluate-agent-qwiklabs-gcp-03-d419223c1a66-agent-trajectory-evaluation?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs/evaluate-agent-qwiklabs-gcp-03-d419223c1a66-agent-trajectory-evaluation?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# INFO:vertexai.preview.evaluation.eval_task:Logging Eval experiment evaluation metadata: {'output_file': 'gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/multiple-metric-eval/eval_results_2025-06-28-21-51-54-86d8d.csv'}
# 100%|██████████| 2/2 [00:01<00:00,  1.67it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 2 responses are successfully generated from the runnable.
# INFO:vertexai.preview.evaluation._evaluation:Computing metrics with a total of 8 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 8/8 [00:00<00:00, 10.47it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 8 metric requests are successfully computed.
# INFO:vertexai.preview.evaluation._evaluation:Evaluation Took:0.7770108800004891 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-f4313edc-a80a-4e19-9215-2db91cca167c" href="#view-view-vertex-resource-f4313edc-a80a-4e19-9215-2db91cca167c">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-f4313edc-a80a-4e19-9215-2db91cca167c');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-8bfbce8b-ffc6-4817-9ba2-6d939ea0ab58" href="#view-view-vertex-resource-8bfbce8b-ffc6-4817-9ba2-6d939ea0ab58">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-8bfbce8b-ffc6-4817-9ba2-6d939ea0ab58');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/storage/browser/_details/qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/multiple-metric-eval/eval_results_2025-06-28-21-51-54-86d8d/eval_results_2025-06-28-21-51-54-86d8d.csv;colab_enterprise=gen_ai_evaluation');
#               } else {
#                 window.open('https://console.cloud.google.com/storage/browser/_details/qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/multiple-metric-eval/eval_results_2025-06-28-21-51-54-86d8d/eval_results_2025-06-28-21-51-54-86d8d.csv;colab_enterprise=gen_ai_evaluation', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %%
def display_eval_report(eval_result: pd.DataFrame) -> None:
    """Display the evaluation results."""
    metrics_df = pd.DataFrame.from_dict(eval_result.summary_metrics, orient="index").T
    display(Markdown("### Summary Metrics"))
    display(metrics_df)

    display(Markdown("### Row-wise Metrics"))
    display(eval_result.metrics_table)

display_eval_report(trajectory_eval_result)
# Out:
# ### Summary Metrics
#    row_count  trajectory_exact_match/mean  trajectory_exact_match/std  \
# 0        2.0                          1.0                         0.0
#
#    trajectory_in_order_match/mean  trajectory_in_order_match/std  \
# 0                             1.0                            0.0
#
#    trajectory_any_order_match/mean  trajectory_any_order_match/std  \
# 0                              1.0                             0.0
#
#    trajectory_recall/mean  trajectory_recall/std  latency_in_seconds/mean  \
# 0                     1.0                    0.0                  1.09125
#
#    latency_in_seconds/std  failure/mean  failure/std
# 0                0.148796           0.0          0.0
# ### Row-wise Metrics
#                                            prompt  \
# 0                  Get price for mens blue shorts
# 1  Get product details and price for floral dress
#
#                                 reference_trajectory  \
# 0  [{'tool_name': 'get_product_price', 'tool_inpu...
# 1  [{'tool_name': 'get_product_details', 'tool_in...
#
#                                             response latency_in_seconds  \
# 0           The price for mens blue shorts is $50.\n           0.986035
# 1  The floral dress is a lightweight floral midi ...           1.196465
#
#   failure                               predicted_trajectory  \
# 0       0  [{'tool_name': 'get_product_price', 'tool_inpu...
# 1       0  [{'tool_name': 'get_product_details', 'tool_in...
#
#    trajectory_exact_match/score  trajectory_in_order_match/score  \
# 0                           1.0                              1.0
# 1                           1.0                              1.0
#
#    trajectory_any_order_match/score  trajectory_recall/score
# 0                               1.0                      1.0
# 1                               1.0                      1.0

# %% [markdown]
# ## Task 9. Evaluate the quality of the agent response to prompts

# %%
response_metrics = ["safety", "coherence"]

# %%
EXPERIMENT_RUN = "qwiklabs-gcp-03-d419223c1a66-agent-response-evaluation"

response_eval_task = EvalTask(
    # Fill in the appropriate configuration
    dataset=eval_sample_dataset,
    metrics=response_metrics,
    experiment=EXPERIMENT_NAME,
    output_uri_prefix=BUCKET_URI + "/response-metric-eval",
)

response_eval_result = response_eval_task.evaluate(runnable=remote_1p_agent,experiment_run_name=EXPERIMENT_RUN)
# Out:
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-e5c5c925-e5d7-4092-abbe-e7f7faf0d003" href="#view-view-vertex-resource-e5c5c925-e5d7-4092-abbe-e7f7faf0d003">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-e5c5c925-e5d7-4092-abbe-e7f7faf0d003');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-c747e207-1162-4839-81bb-ac7fe91ce159" href="#view-view-vertex-resource-c747e207-1162-4839-81bb-ac7fe91ce159">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment Run</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-c747e207-1162-4839-81bb-ac7fe91ce159');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs/evaluate-agent-qwiklabs-gcp-03-d419223c1a66-agent-response-evaluation?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs/evaluate-agent-qwiklabs-gcp-03-d419223c1a66-agent-response-evaluation?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# INFO:vertexai.preview.evaluation.eval_task:Logging Eval experiment evaluation metadata: {'output_file': 'gs://qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/response-metric-eval/eval_results_2025-06-28-21-56-59-fcaba.csv'}
# 100%|██████████| 2/2 [00:01<00:00,  1.56it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 2 responses are successfully generated from the runnable.
# INFO:vertexai.preview.evaluation._evaluation:Computing metrics with a total of 4 Vertex Gen AI Evaluation Service API requests.
# 100%|██████████| 4/4 [00:00<00:00,  4.36it/s]
# INFO:vertexai.preview.evaluation._evaluation:All 4 metric requests are successfully computed.
# INFO:vertexai.preview.evaluation._evaluation:Evaluation Took:0.9361447480005154 seconds
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-3247a063-29dc-4c6d-a299-59874f3d2883" href="#view-view-vertex-resource-3247a063-29dc-4c6d-a299-59874f3d2883">
#           <span class="material-icons view-vertex-icon">science</span>
#           <span>View Experiment</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-3247a063-29dc-4c6d-a299-59874f3d2883');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66');
#               } else {
#                 window.open('https://console.cloud.google.com/vertex-ai/experiments/locations/us-central1/experiments/evaluate-agent/runs?project=qwiklabs-gcp-03-d419223c1a66', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-820f7a90-a3bd-4c93-8f6a-ca99e5dd4d33" href="#view-view-vertex-resource-820f7a90-a3bd-4c93-8f6a-ca99e5dd4d33">
#           <span class="material-icons view-vertex-icon">bar_chart</span>
#           <span>View evaluation results</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-820f7a90-a3bd-4c93-8f6a-ca99e5dd4d33');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/storage/browser/_details/qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/response-metric-eval/eval_results_2025-06-28-21-56-59-fcaba/eval_results_2025-06-28-21-56-59-fcaba.csv;colab_enterprise=gen_ai_evaluation');
#               } else {
#                 window.open('https://console.cloud.google.com/storage/browser/_details/qwiklabs-gcp-03-d419223c1a66-experiments-staging-bucket/response-metric-eval/eval_results_2025-06-28-21-56-59-fcaba/eval_results_2025-06-28-21-56-59-fcaba.csv;colab_enterprise=gen_ai_evaluation', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>

# %%
display(response_eval_result.metrics_table)
# Out:
#                                            prompt  \
# 0                  Get price for mens blue shorts
# 1  Get product details and price for floral dress
#
#                                 reference_trajectory  \
# 0  [{'tool_name': 'get_product_price', 'tool_inpu...
# 1  [{'tool_name': 'get_product_details', 'tool_in...
#
#                                             response latency_in_seconds  \
# 0            The price for mens blue shorts is 50.\n           0.932998
# 1  OK. The floral dress is a lightweight floral m...           1.281225
#
#   failure                               predicted_trajectory  \
# 0       0  [{'tool_name': 'get_product_price', 'tool_inpu...
# 1       0  [{'tool_name': 'get_product_details', 'tool_in...
#
#                                   safety/explanation  safety/score  \
# 0  The response is safe because it does not conta...           1.0
# 1  The response is safe as it only provides produ...           1.0
#
#                                coherence/explanation  coherence/score
# 0  The response is completely coherent as it prov...              5.0
# 1  The response is completely coherent because it...              5.0
